# %%
import streamlit as st
import os
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
import getpass

# %%
st.set_page_config(page_title="City One-Word Describer", page_icon="🌎")

st.title("🌆 One-Word City Describer")
st.write("Type any city name and I will describe it in **one word**.")
# Out:
# 2025-12-10 19:14:22.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:22.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:22.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:22.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:22.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:22.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:22.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
api_key = "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"

if not api_key:
    st.info("Please enter your Groq API Key to continue.")
    st.stop()

# %%
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    groq_api_key=api_key
)

# %%
prompt = PromptTemplate(
    input_variables=["city"],
    template="In ONE word only, describe the city {city}. Output just the single word, nothing else."
)

# %%
#llm.invoke("tell about Berlin")

# %%
city_name = st.text_input("Type city name:")
# Out:
# 2025-12-10 19:14:32.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:32.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:32.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:32.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:32.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:32.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:32.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if st.button("Describe"):
    if city_name.strip() == "":
        st.error("Please enter a valid city name.")
    else:
        chain = prompt | llm
        response = chain.invoke({"city": city_name})

        st.success(f"**One-word description for {city_name}:**")
        st.markdown(f"### 🏷️ {response.content.strip()}")
# Out:
# 2025-12-10 19:14:33.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:33.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:33.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:33.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:33.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-10 19:14:33.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
